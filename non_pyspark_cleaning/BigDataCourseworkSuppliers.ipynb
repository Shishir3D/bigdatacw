# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
suppliers_df = pd.read_csv("/content/drive/MyDrive/BigDataAndDataMiningCoursework/








































































































































































































































































































































































































+++++++++++++++++++++++++++++++++/suppliers.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_13141/2310231145.py in <cell line: 0>()
# ----> 1 suppliers_df = pd.read_csv("/content/drive/MyDrive/BigDataAndDataMiningCoursework/Coursework_dataset/suppliers.csv")
#
# ...

# %%
suppliers_df.info()

# %%
# This returns all rows where the customer_id is a repeat
duplicates = suppliers_df[df_customer.duplicated('supplier_id', keep=False)]

# Sorting helps you see the pairs side-by-side
duplicates.sort_values(by='supplier_id')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13141/573443033.py in <cell line: 0>()
#       1 # This returns all rows where the customer_id is a repeat
# ----> 2 duplicates = suppliers_df[df_customer.duplicated('supplier_id', keep=False)]
#       3
#       4 # Sorting helps you see the pairs side-by-side
#       5 duplicates.sort_values(by='supplier_id')
#
# NameError: name 'suppliers_df' is not defined

# %%
suppliers_df.isnull().sum()
# Out:
# supplier_id       0
# supplier_name     0
# country           0
# contact_email     0
# contract_start    0
# dtype: int64

# %%
duplicated_reviews = suppliers_df[suppliers_df["supplier_id"].duplicated(keep=False)]
duplicated_reviews.sort_values("supplier_id")
# Out:
# Empty DataFrame
# Columns: [supplier_id, supplier_name, country, contact_email, contract_start]
# Index: []

# %%
suppliers_df
# Out:
#     supplier_id                     supplier_name country  \
# 0      supp_001         Himalayan Traders Pvt Ltd   Nepal
# 1      supp_002              Sagarmatha Suppliers   Nepal
# 2      supp_003                Nepal Commerce Hub   Nepal
# 3      supp_004            Kathmandu Wholesale Co   Nepal
# 4      supp_005             Lumbini Trading House   Nepal
# ..          ...                               ...     ...
# 195    supp_196     Dubai Wholesale Hub Branch 17     UAE
# 196    supp_197  Abu Dhabi Trading Corp Branch 18     UAE
# 197    supp_198    Sharjah Supply Chain Branch 19     UAE
# 198    supp_199   Emirates Commerce Ltd Branch 20     UAE
# 199    supp_200      Gulf Trading House Branch 21     UAE
#
#                    contact_email contract_start
# 0      contact@himalayantra1.com       4/1/2016
# 1      contact@sagarmathasu2.com      4/13/2015
# 2      contact@nepalcommerc3.com      1/31/2018
# 3      contact@kathmanduwho4.com      9/30/2017
# ...

# %%
suppliers_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
suppliers_df["contract_start"] = pd.to_datetime(suppliers_df["contract_start"], errors='coerce')

# %%
suppliers_df
# Out:
#     supplier_id                     supplier_name country  \
# 0      supp_001         Himalayan Traders Pvt Ltd   Nepal
# 1      supp_002              Sagarmatha Suppliers   Nepal
# 2      supp_003                Nepal Commerce Hub   Nepal
# 3      supp_004            Kathmandu Wholesale Co   Nepal
# 4      supp_005             Lumbini Trading House   Nepal
# ..          ...                               ...     ...
# 195    supp_196     Dubai Wholesale Hub Branch 17     UAE
# 196    supp_197  Abu Dhabi Trading Corp Branch 18     UAE
# 197    supp_198    Sharjah Supply Chain Branch 19     UAE
# 198    supp_199   Emirates Commerce Ltd Branch 20     UAE
# 199    supp_200      Gulf Trading House Branch 21     UAE
#
#                    contact_email contract_start
# 0      contact@himalayantra1.com     2016-04-01
# 1      contact@sagarmathasu2.com     2015-04-13
# 2      contact@nepalcommerc3.com     2018-01-31
# 3      contact@kathmanduwho4.com     2017-09-30
# ...

# %%
suppliers_df.to_csv('suppliers.csv', index=False)
print("df_product exported successfully to 'products.csv'")
# Out:
# df_product exported successfully to 'products.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
